# %%
import pandas as pd
import datetime as dt
from github import Github
from credentials import username, password

# %%
g = Github(username(), password())  # credentials for github login
repos = g.get_user().get_repos()  # iterable; all the repos associated with the profile incl. organizations

# %%
ha_1 = '2is50-2019-2020-homework-assignment-1-pair-'  # repos to filter for; 
ha_len = len('2is50-2019-2020-homework-assignment-1-')  # will be used for retrieving pair# by indexing
staff_ids = ['sakce', 'kvidelov', 'mackees', 'sakehl', 'thatmariia', 'wstomv', 'sansteTUe', 'HDylanTV', 'gzwaan', 'dmarinissen']

pair_numb = []
authors = []
emails = []
date_time = []
commit_messages = []

# %%
for repo in repos: # iterating over all repositories associated with the login account

    if 'with-ta' in repo.name:
        pass

    elif ha_1 in repo.name:  # filtering only the assignment repos

        print("\n", repo.name)
        commits = repo.get_commits()
        
        for commit in commits:
            
            added_lines = commit.stats.additions
            deleted_lines = commit.stats.deletions

            print('Commit', commit, 'Date', commit.commit.author.date)
            print('Author', commit.author.login)
            print('Additions', added_lines)
            print('Deletions', deleted_lines)
# Out:
#  2is50-2019-2020-homework-assignment-1-pair-10
# Commit Commit(sha="6fba18aa17a7dd42c800ef4e65657873ac1083bb") Date 2020-05-17 13:40:17
# Author GiuliaFliescher
# Additions 13
# Deletions 5
# Commit Commit(sha="a5709ab3ae73ff97813b374f3e1ffc833b044a3d") Date 2020-05-17 13:39:51
# Author GiuliaFliescher
# Additions 1
# Deletions 5
# Commit Commit(sha="b4bcb7bfd9e15cd9b8f54681f5ef5736740a289d") Date 2020-05-17 13:13:38
# Author GiuliaFliescher
# Additions 6
# Deletions 5
# Commit Commit(sha="30b4abef9dea29d96d33edbfbdeebeed3920082d") Date 2020-05-17 13:13:06
# Author GiuliaFliescher
# Additions 1
# Deletions 1
# Commit Commit(sha="adbdff7827cfca9c49365b82faafeb1f0bf92f07") Date 2020-05-17 13:02:50
# Author GiuliaFliescher
# Additions 7
# Deletions 0
# Commit Commit(sha="16e3192f594b4091f4a23360de402c142ac43205") Date 2020-05-17 13:02:12
# Author GiuliaFliescher
# Additions 53
# Deletions 7
# Commit Commit(sha="0cea82c6b35835c5c0afe7b19f56fd3bc7f07780") Date 2020-05-13 10:16:42
# Author Dravurius
# Additions 22
# Deletions 2
# Commit Commit(sha="07d9d8790bae03c5a62319b72387ab9af9110d2f") Date 2020-05-13 09:33:37
# Author Dravurius
# Additions 30
# Deletions 64
# Commit Commit(sha="385f18264c51cc064dd5181eb9b4e40f24305121") Date 2020-05-12 21:18:22
# Author Dravurius
# Additions 40
# Deletions 8
# Commit Commit(sha="d05df4630aa0440409b1a5e8fc6be9141deaed43") Date 2020-05-12 14:32:25
# Author GiuliaFliescher
# Additions 42
# Deletions 1
# Commit Commit(sha="fa62afcff35c7764eb6dae6215a1d53a219734d7") Date 2020-05-08 09:05:50
# Author Dravurius
# Additions 4
# Deletions 4
# Commit Commit(sha="83a570ca692311e30573f707d9cd7ab3716b9122") Date 2020-05-08 09:04:56
# Author Dravurius
# Additions 2
# Deletions 2
# Commit Commit(sha="e50567f5f770e26e6062ae5a738d0afb33141638") Date 2020-05-08 09:04:30
# Author Dravurius
# Additions 8
# Deletions 1
# Commit Commit(sha="3edf8f20c72547d5673f5e64507889a13beb1b49") Date 2020-05-07 20:42:46
# Author Dravurius
# Additions 0
# Deletions 5
# Commit Commit(sha="0318aa251546c9fe9f8a8012404dcb8606bc63a6") Date 2020-05-07 20:41:47
# Author Dravurius
# Additions 6
# Deletions 1
# Commit Commit(sha="ab186bdda047fff7cb0ff197f93345f3b425abc4") Date 2020-05-07 14:37:37
# Author Dravurius
# Additions 20
# Deletions 9
# Commit Commit(sha="af999007263ae048f8f6735f3dcbf618193f515e") Date 2020-05-07 14:37:27
# Author Dravurius
# Additions 3
# Deletions 2
# Commit Commit(sha="636a94fce828ec20b81fbd61f87213d312297119") Date 2020-05-07 14:37:10
# Author Dravurius
# Additions 1
# Deletions 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f601c70a3ca2> in <module>
#      11         for commit in commits:
#      12
# ---> 13             added_lines = commit.stats.additions
#      14             deleted_lines = commit.stats.deletions
#      15
#
# /usr/local/lib/python3.7/site-packages/github/Commit.py in stats(self)
#     121         :type: :class:`github.CommitStats.CommitStats`
#     122         """
# --> 123         self._completeIfNotSet(self._stats)
#     124         return self._stats.value
#     125
#
# /usr/local/lib/python3.7/site-packages/github/GithubObject.py in _completeIfNotSet(self, value)
#     297     def _completeIfNotSet(self, value):
#     298         if value is NotSet:
# --> 299             self._completeIfNeeded()
#     300
#     301     def _completeIfNeeded(self):
#
# /usr/local/lib/python3.7/site-packages/github/GithubObject.py in _completeIfNeeded(self)
#     301     def _completeIfNeeded(self):
#     302         if not self.__completed:
# --> 303             self.__complete()
#     304
#     305     def __complete(self):
#
# /usr/local/lib/python3.7/site-packages/github/GithubObject.py in __complete(self)
#     308                 400, "Returned object contains no URL"
#     309             )
# --> 310         headers, data = self._requester.requestJsonAndCheck("GET", self._url.value)
#     311         self._storeAndUseAttributes(headers, data)
#     312         self.__completed = True
#
# /usr/local/lib/python3.7/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# /usr/local/lib/python3.7/site-packages/github/Requester.py in requestJson(self, verb, url, parameters, headers, input, cnx)
#     408             return "application/json", json.dumps(input)
#     409
# --> 410         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     411
#     412     def requestMultipart(
#
# /usr/local/lib/python3.7/site-packages/github/Requester.py in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     470
#     471         status, responseHeaders, output = self.__requestRaw(
# --> 472             cnx, verb, url, requestHeaders, encoded_input
#     473         )
#     474
#
# /usr/local/lib/python3.7/site-packages/github/Requester.py in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     496             cnx = self.__createConnection()
#     497         cnx.request(verb, url, input, requestHeaders)
# --> 498         response = cnx.getresponse()
#     499
#     500         status = response.status
#
# /usr/local/lib/python3.7/site-packages/github/Requester.py in getresponse(self)
#     114             timeout=self.timeout,
#     115             verify=self.verify,
# --> 116             allow_redirects=False,
#     117         )
#     118         return RequestsResponse(r)
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
commits = repos[0].get_commits()

# %%
for commit in commits:
    print(commit.)
# Out:
# Commit(sha="6eae881b66327b6b55794d4f1c53b027acc425e8")
# Commit(sha="6470cca944a07cd49a7d9007845e405b301533c1")
# Commit(sha="03c97c3b593fbcbc980f884c5866a288589b8f06")
# Commit(sha="b26278d8c75a9d9f4f93d9f88a02babe0cca260a")
# Commit(sha="67e8b2f4399ed6304603d4314c159fb9affeb09c")
# Commit(sha="0f7abd51d4ae213c11aa1c323fd80319f703e808")
# Commit(sha="e383d724c3c2ab9a858c8e33e99f917a02968cc2")
# Commit(sha="77313c1aefb91b78913438d0831e81014e4aa8a0")
